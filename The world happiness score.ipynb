# %% [markdown]
# # Description

# %% [markdown]
# ### Context
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.
#
# ### Content
# The happiness scores and rankings use data from the Gallup World Poll. The scores are based on answers to the main life evaluation question asked in the poll. This question, known as the Cantril ladder, asks respondents to think of a ladder with the best possible life for them being a 10 and the worst possible life being a 0 and to rate their own current lives on that scale. The scores are from nationally representative samples for the years 2013-2016 and use the Gallup weights to make the estimates representative. The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.
#
# ### Inspiration
# What countries or regions rank the highest in overall happiness and each of the six factors contributing to happiness? How did country ranks or scores change between the 2015 and 2016 as well as the 2016 and 2017 reports? Did any country experience a significant increase or decrease in happiness?
#
# **What is Dystopia?**
#
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.
#
# ****What are the residuals?****
#
# The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either over- or under-explain average 2014-2016 life evaluations. These residuals have an average value of approximately zero over the whole set of countries. Figure 2.2 shows the average residual for each country when the equation in Table 2.1 is applied to average 2014- 2016 data for the six variables in that country. We combine these residuals with the estimate for life evaluations in Dystopia so that the combined bar will always have positive values. As can be seen in Figure 2.2, although some life evaluation residuals are quite large, occasionally exceeding one point on the scale from 0 to 10, they are always much smaller than the calculated value in Dystopia, where the average life is rated at 1.85 on the 0 to 10 scale.
#
# ****What do the columns succeeding the Happiness Score(like Family, Generosity, etc.) describe?****
#
# The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country.
# The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country as stated in the previous answer.
#
# If you add all these factors up, you get the happiness score so it might be un-reliable to model them to predict Happiness Scores.

# %% [markdown]
# ## Importing Libraries and Datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2015 =pd.read_csv("2015.csv")
df2016 =pd.read_csv("2016.csv")
df2017 =pd.read_csv("2017.csv")
df2018 =pd.read_csv("2018.csv")
df2019 =pd.read_csv("2019.csv")

# %%
display(df2015.head())
display(df2016.head())
display(df2017.head())
display(df2018.head())
display(df2019.head())
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
display(df2015.describe())
display(df2016.describe())
display(df2017.describe())
display(df2018.describe())
display(df2019.describe())
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
col_names=['country','happiness_rank','happiness_score','family','gdp','life_expectancy','freedom','govt_corruption','generosity']

# %% [markdown]
# ### Data 2015

# %%
df2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df2015=df2015[['Country', 'Happiness Rank', 'Happiness Score','Family','Economy (GDP per Capita)','Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)','Generosity' ]]

# %%
df2015.head()
# Out:
#        Country  Happiness Rank  Happiness Score   Family  \
# 0  Switzerland               1            7.587  1.34951
# 1      Iceland               2            7.561  1.40223
# 2      Denmark               3            7.527  1.36058
# 3       Norway               4            7.522  1.33095
# 4       Canada               5            7.427  1.32261
#
#    Economy (GDP per Capita)  Health (Life Expectancy)  Freedom  \
# 0                   1.39651                   0.94143  0.66557
# 1                   1.30232                   0.94784  0.62877
# 2                   1.32548                   0.87464  0.64938
# 3                   1.45900                   0.88521  0.66973
# 4                   1.32629                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity
# 0                        0.41978     0.29678
# 1                        0.14145     0.43630
# 2                        0.48357     0.34139
# 3                        0.36503     0.34699
# ...

# %%
df2015.columns=col_names

# %%
df2015.head()
# Out:
#        country  happiness_rank  happiness_score   family      gdp  \
# 0  Switzerland               1            7.587  1.34951  1.39651
# 1      Iceland               2            7.561  1.40223  1.30232
# 2      Denmark               3            7.527  1.36058  1.32548
# 3       Norway               4            7.522  1.33095  1.45900
# 4       Canada               5            7.427  1.32261  1.32629
#
#    life_expectancy  freedom  govt_corruption  generosity
# 0          0.94143  0.66557          0.41978     0.29678
# 1          0.94784  0.62877          0.14145     0.43630
# 2          0.87464  0.64938          0.48357     0.34139
# 3          0.88521  0.66973          0.36503     0.34699
# 4          0.90563  0.63297          0.32957     0.45811

# %% [markdown]
# ### Data 2016

# %%
df2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df2016=df2016[['Country', 'Happiness Rank', 'Happiness Score',
       'Family','Economy (GDP per Capita)', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity']]

# %%
df2016.columns=col_names

# %%
df2016.head()
# Out:
#        country  happiness_rank  happiness_score   family      gdp  \
# 0      Denmark               1            7.526  1.16374  1.44178
# 1  Switzerland               2            7.509  1.14524  1.52733
# 2      Iceland               3            7.501  1.18326  1.42666
# 3       Norway               4            7.498  1.12690  1.57744
# 4      Finland               5            7.413  1.13464  1.40598
#
#    life_expectancy  freedom  govt_corruption  generosity
# 0          0.79504  0.57941          0.44453     0.36171
# 1          0.86303  0.58557          0.41203     0.28083
# 2          0.86733  0.56624          0.14975     0.47678
# 3          0.79579  0.59609          0.35776     0.37895
# 4          0.81091  0.57104          0.41004     0.25492

# %% [markdown]
# ### Data 2017

# %%
df2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
df2017=df2017[['Country', 'Happiness.Rank', 'Happiness.Score','Family','Economy..GDP.per.Capita.','Health..Life.Expectancy.', 'Freedom', 
       'Trust..Government.Corruption.','Generosity',]]

# %%
df2017.columns=col_names

# %%
df2017.head()
# Out:
#        country  happiness_rank  happiness_score    family       gdp  \
# 0       Norway               1            7.537  1.533524  1.616463
# 1      Denmark               2            7.522  1.551122  1.482383
# 2      Iceland               3            7.504  1.610574  1.480633
# 3  Switzerland               4            7.494  1.516912  1.564980
# 4      Finland               5            7.469  1.540247  1.443572
#
#    life_expectancy   freedom  govt_corruption  generosity
# 0         0.796667  0.635423         0.315964    0.362012
# 1         0.792566  0.626007         0.400770    0.355280
# 2         0.833552  0.627163         0.153527    0.475540
# 3         0.858131  0.620071         0.367007    0.290549
# 4         0.809158  0.617951         0.382612    0.245483

# %% [markdown]
# ### Data 2018

# %%
df2018.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df2018=df2018[['Country or region','Overall rank','Score', 'Social support','GDP per capita','Healthy life expectancy','Freedom to make life choices','Perceptions of corruption',
             'Generosity' ]]

# %%
df2018.columns=col_names

# %%
df2018.head()
# Out:
#        country  happiness_rank  happiness_score  family    gdp  \
# 0      Finland               1            7.632   1.592  1.305
# 1       Norway               2            7.594   1.582  1.456
# 2      Denmark               3            7.555   1.590  1.351
# 3      Iceland               4            7.495   1.644  1.343
# 4  Switzerland               5            7.487   1.549  1.420
#
#    life_expectancy  freedom  govt_corruption  generosity
# 0            0.874    0.681            0.393       0.202
# 1            0.861    0.686            0.340       0.286
# 2            0.868    0.683            0.408       0.284
# 3            0.914    0.677            0.138       0.353
# 4            0.927    0.660            0.357       0.256

# %% [markdown]
# ### Data 2019

# %%
df2019.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df2019=df2019[['Country or region','Overall rank','Score', 'Social support','GDP per capita','Healthy life expectancy','Freedom to make life choices','Perceptions of corruption',
             'Generosity']]

# %%
df2019.columns=col_names

# %%
df2019.head()
# Out:
#        country  happiness_rank  happiness_score  family    gdp  \
# 0      Finland               1            7.769   1.587  1.340
# 1      Denmark               2            7.600   1.573  1.383
# 2       Norway               3            7.554   1.582  1.488
# 3      Iceland               4            7.494   1.624  1.380
# 4  Netherlands               5            7.488   1.522  1.396
#
#    life_expectancy  freedom  govt_corruption  generosity
# 0            0.986    0.596            0.393       0.153
# 1            0.996    0.592            0.410       0.252
# 2            1.028    0.603            0.341       0.271
# 3            1.026    0.591            0.118       0.354
# 4            0.999    0.557            0.298       0.322

# %%
df2015['year']=2015
df2016['year']=2016
df2017['year']=2017
df2018['year']=2018
df2019['year']=2019

# %% [markdown]
# ### Combining all the dataset in one

# %%
df=df2015.append([df2016,df2017,df2018,df2019])

# %%
df.shape
# Out:
# (782, 10)

# %% [markdown]
# #### Checking and removing Null values

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['govt_corruption'], dtype='object')

# %%
df['govt_corruption'].isnull().any()
# Out:
# True

# %%
df.dropna(subset=['govt_corruption'],axis=0, inplace=True)

# %% [markdown]
# # Getting insights of the data.

# %%
df.shape
# Out:
# (781, 10)

# %%
df.dtypes
# Out:
# country             object
# happiness_rank       int64
# happiness_score    float64
# family             float64
# gdp                float64
# life_expectancy    float64
# freedom            float64
# govt_corruption    float64
# generosity         float64
# year                 int64
# dtype: object

# %% [markdown]
# ### Relation between happiness score variable by scatter plot

# %% [markdown]
# ### Data 2015

# %%
df2015.plot(kind='scatter', x='family', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,1))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2015')

df2015.plot(kind='scatter', x='gdp', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,2))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2015')

df2015.plot(kind='scatter', x='life_expectancy', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,3))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2015')

df2015.plot(kind='scatter', x='freedom', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,4))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2015')

df2015.plot(kind='scatter', x='govt_corruption', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,5))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2015')

df2015.plot(kind='scatter', x='generosity', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,6))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2015')
# Out:
# Text(0.5, 1.0, '2015')

# %% [markdown]
# ## Data 2016

# %%
df2016.plot(kind='scatter', x='family', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,1))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2016')

df2016.plot(kind='scatter', x='gdp', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,2))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2016')

df2016.plot(kind='scatter', x='life_expectancy', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,3))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2016')

df2016.plot(kind='scatter', x='freedom', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,4))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2016')

df2016.plot(kind='scatter', x='govt_corruption', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,5))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2016')

df2016.plot(kind='scatter', x='generosity', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,6))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2016')
# Out:
# Text(0.5, 1.0, '2016')

# %% [markdown]
# ### Data 2017

# %%
df2017.plot(kind='scatter', x='family', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,1))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2017')

df2017.plot(kind='scatter', x='gdp', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,2))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2017')

df2017.plot(kind='scatter', x='life_expectancy', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,3))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2017')

df2017.plot(kind='scatter', x='freedom', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,4))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2017')

df2017.plot(kind='scatter', x='govt_corruption', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,5))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2017')

df2017.plot(kind='scatter', x='generosity', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,6))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2017')
# Out:
# Text(0.5, 1.0, '2017')

# %% [markdown]
# ### Data 2018

# %%
df2018.plot(kind='scatter', x='family', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,1))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2018')

df2018.plot(kind='scatter', x='gdp', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,2))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2018')

df2018.plot(kind='scatter', x='life_expectancy', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,3))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2018')

df2018.plot(kind='scatter', x='freedom', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,4))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2018')

df2018.plot(kind='scatter', x='govt_corruption', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,5))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2018')

df2018.plot(kind='scatter', x='generosity', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,6))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2018')
# Out:
# Text(0.5, 1.0, '2018')

# %% [markdown]
# ### Data 2019

# %%
df2019.plot(kind='scatter', x='family', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,1))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2019')

df2019.plot(kind='scatter', x='gdp', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,2))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2019')

df2019.plot(kind='scatter', x='life_expectancy', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,3))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2019')

df2019.plot(kind='scatter', x='freedom', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,4))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2019')

df2019.plot(kind='scatter', x='govt_corruption', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,5))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2019')

df2019.plot(kind='scatter', x='generosity', y='happiness_score',alpha = 0.5,color = 'red',figsize=(10,5),subplots = (3,2,6))
plt.xlabel('Economy')
plt.ylabel('Happiness Score')
plt.title('2019')
# Out:
# Text(0.5, 1.0, '2019')

# %%
df_test=df[['year','happiness_score']]
df_grp=df_test.groupby(['year'],as_index=False).mean()
df_grp
# Out:
#    year  happiness_score
# 0  2015         5.375734
# 1  2016         5.382185
# 2  2017         5.354019
# 3  2018         5.366897
# 4  2019         5.407096

# %% [markdown]
# # 2015 data correlation, reg plot, heatmap

# %%
corr_2015=df2015.corr()
corr_2015
# Out:
#                  happiness_rank  happiness_score    family       gdp  \
# happiness_rank         1.000000        -0.992105 -0.733644 -0.785267
# happiness_score       -0.992105         1.000000  0.740605  0.780966
# family                -0.733644         0.740605  1.000000  0.645299
# gdp                   -0.785267         0.780966  0.645299  1.000000
# life_expectancy       -0.735613         0.724200  0.531104  0.816478
# freedom               -0.556886         0.568211  0.441518  0.370300
# govt_corruption       -0.372315         0.395199  0.205605  0.307885
# generosity            -0.160142         0.180319  0.087513 -0.010465
# year                        NaN              NaN       NaN       NaN
#
#                  life_expectancy   freedom  govt_corruption  generosity  year
# happiness_rank         -0.735613 -0.556886        -0.372315   -0.160142   NaN
# happiness_score         0.724200  0.568211         0.395199    0.180319   NaN
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(corr_2015,cmap='Blues',annot=True)
plt.title('2015',fontsize=25)
# Out:
# Text(0.5, 1, '2015')

# %%
fig=plt.figure(figsize=(15, 10))

ax1 = fig.add_subplot(321)
sns.regplot(x='family',y='happiness_score',data=df2015, ax=ax1)

ax2 = fig.add_subplot(322)
sns.regplot(x='gdp', y='happiness_score',data=df2015, ax=ax2)

ax3 = fig.add_subplot(323)
sns.regplot(x='life_expectancy', y='happiness_score',data=df2015, ax=ax3)

ax4 = fig.add_subplot(324)
sns.regplot(x='freedom', y='happiness_score',data=df2015, ax=ax4)

ax5 = fig.add_subplot(325)
sns.regplot(x='govt_corruption', y='happiness_score',data=df2015, ax=ax5)

ax6 = fig.add_subplot(326)
sns.regplot(x='generosity', y='happiness_score',data=df2015, ax=ax6)

# %% [markdown]
# # 2016 data correlation, reg plot, heatmap

# %%
corr_2016=df2016.corr()
corr_2016
# Out:
#                  happiness_rank  happiness_score    family       gdp  \
# happiness_rank         1.000000        -0.995743 -0.733276 -0.793577
# happiness_score       -0.995743         1.000000  0.739252  0.790322
# family                -0.733276         0.739252  1.000000  0.669540
# gdp                   -0.793577         0.790322  0.669540  1.000000
# life_expectancy       -0.767991         0.765384  0.588377  0.837067
# freedom               -0.557169         0.566827  0.450208  0.362283
# govt_corruption       -0.387102         0.402032  0.213561  0.294185
# generosity            -0.145369         0.156848  0.089629 -0.025531
# year                        NaN              NaN       NaN       NaN
#
#                  life_expectancy   freedom  govt_corruption  generosity  year
# happiness_rank         -0.767991 -0.557169        -0.387102   -0.145369   NaN
# happiness_score         0.765384  0.566827         0.402032    0.156848   NaN
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(corr_2016,cmap='Blues',annot=True)
plt.title('2016',fontsize=25)
# Out:
# Text(0.5, 1, '2016')

# %%
fig=plt.figure(figsize=(15, 10))

ax1 = fig.add_subplot(321)
sns.regplot(x='family',y='happiness_score',data=df2016, ax=ax1)

ax2 = fig.add_subplot(322)
sns.regplot(x='gdp', y='happiness_score',data=df2016, ax=ax2)

ax3 = fig.add_subplot(323)
sns.regplot(x='life_expectancy', y='happiness_score',data=df2016, ax=ax3)

ax4 = fig.add_subplot(324)
sns.regplot(x='freedom', y='happiness_score',data=df2016, ax=ax4)

ax5 = fig.add_subplot(325)
sns.regplot(x='govt_corruption', y='happiness_score',data=df2016, ax=ax5)

ax6 = fig.add_subplot(326)
sns.regplot(x='generosity', y='happiness_score',data=df2016, ax=ax6)

# %% [markdown]
# # 2017 data correlation, reg plot, heatmap

# %%
corr_2017=df2017.corr()
corr_2017
# Out:
#                  happiness_rank  happiness_score    family       gdp  \
# happiness_rank         1.000000        -0.992774 -0.736753 -0.813244
# happiness_score       -0.992774         1.000000  0.752737  0.812469
# family                -0.736753         0.752737  1.000000  0.688296
# gdp                   -0.813244         0.812469  0.688296  1.000000
# life_expectancy       -0.780716         0.781951  0.612080  0.843077
# freedom               -0.551608         0.570137  0.424966  0.369873
# govt_corruption       -0.405842         0.429080  0.231841  0.350944
# generosity            -0.132620         0.155256  0.051693 -0.019011
# year                        NaN              NaN       NaN       NaN
#
#                  life_expectancy   freedom  govt_corruption  generosity  year
# happiness_rank         -0.780716 -0.551608        -0.405842   -0.132620   NaN
# happiness_score         0.781951  0.570137         0.429080    0.155256   NaN
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(corr_2017,cmap='Blues',annot=True)
plt.title('2017',fontsize=25)
# Out:
# Text(0.5, 1, '2017')

# %%
fig=plt.figure(figsize=(15, 10))

ax1 = fig.add_subplot(321)
sns.regplot(x='family',y='happiness_score',data=df2017, ax=ax1)

ax2 = fig.add_subplot(322)
sns.regplot(x='gdp', y='happiness_score',data=df2017, ax=ax2)

ax3 = fig.add_subplot(323)
sns.regplot(x='life_expectancy', y='happiness_score',data=df2017, ax=ax3)

ax4 = fig.add_subplot(324)
sns.regplot(x='freedom', y='happiness_score',data=df2017, ax=ax4)

ax5 = fig.add_subplot(325)
sns.regplot(x='govt_corruption', y='happiness_score',data=df2017, ax=ax5)

ax6 = fig.add_subplot(326)
sns.regplot(x='generosity', y='happiness_score',data=df2017, ax=ax6)

# %% [markdown]
# # 2018 data correlation, reg plot, heatmap

# %%
corr_2018=df2018.corr()
corr_2018
# Out:
#                  happiness_rank  happiness_score    family       gdp  \
# happiness_rank         1.000000        -0.991749 -0.737500 -0.805897
# happiness_score       -0.991749         1.000000  0.745760  0.802124
# family                -0.737500         0.745760  1.000000  0.672080
# gdp                   -0.805897         0.802124  0.672080  1.000000
# life_expectancy       -0.778700         0.775814  0.667288  0.844273
# freedom               -0.530786         0.544280  0.411087  0.332275
# govt_corruption       -0.371133         0.405292  0.218364  0.319582
# generosity            -0.103602         0.135825  0.018226 -0.011241
# year                        NaN              NaN       NaN       NaN
#
#                  life_expectancy   freedom  govt_corruption  generosity  year
# happiness_rank         -0.778700 -0.530786        -0.371133   -0.103602   NaN
# happiness_score         0.775814  0.544280         0.405292    0.135825   NaN
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(corr_2018,cmap='Blues',annot=True)
plt.title('2018',fontsize=25)
# Out:
# Text(0.5, 1, '2018')

# %%
fig=plt.figure(figsize=(15, 10))

ax1 = fig.add_subplot(321)
sns.regplot(x='family',y='happiness_score',data=df2018, ax=ax1)

ax2 = fig.add_subplot(322)
sns.regplot(x='gdp', y='happiness_score',data=df2018, ax=ax2)

ax3 = fig.add_subplot(323)
sns.regplot(x='life_expectancy', y='happiness_score',data=df2018, ax=ax3)

ax4 = fig.add_subplot(324)
sns.regplot(x='freedom', y='happiness_score',data=df2018, ax=ax4)

ax5 = fig.add_subplot(325)
sns.regplot(x='govt_corruption', y='happiness_score',data=df2018, ax=ax5)

ax6 = fig.add_subplot(326)
sns.regplot(x='generosity', y='happiness_score',data=df2018, ax=ax6)

# %% [markdown]
# # 2019 data correlation, reg plot, heatmap

# %%
corr_2019=df2019.corr()
corr_2019
# Out:
#                  happiness_rank  happiness_score    family       gdp  \
# happiness_rank         1.000000        -0.989096 -0.767465 -0.801947
# happiness_score       -0.989096         1.000000  0.777058  0.793883
# family                -0.767465         0.777058  1.000000  0.754906
# gdp                   -0.801947         0.793883  0.754906  1.000000
# life_expectancy       -0.787411         0.779883  0.719009  0.835462
# freedom               -0.546606         0.566742  0.447333  0.379079
# govt_corruption       -0.351959         0.385613  0.181899  0.298920
# generosity            -0.047993         0.075824 -0.048126 -0.079662
# year                        NaN              NaN       NaN       NaN
#
#                  life_expectancy   freedom  govt_corruption  generosity  year
# happiness_rank         -0.787411 -0.546606        -0.351959   -0.047993   NaN
# happiness_score         0.779883  0.566742         0.385613    0.075824   NaN
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(corr_2019,cmap='Blues',annot=True)
plt.title('2019',fontsize=25)
# Out:
# Text(0.5, 1, '2019')

# %%
fig=plt.figure(figsize=(15, 10))

ax1 = fig.add_subplot(321)
sns.regplot(x='family',y='happiness_score',data=df2019, ax=ax1)

ax2 = fig.add_subplot(322)
sns.regplot(x='gdp', y='happiness_score',data=df2019, ax=ax2)

ax3 = fig.add_subplot(323)
sns.regplot(x='life_expectancy', y='happiness_score',data=df2019, ax=ax3)

ax4 = fig.add_subplot(324)
sns.regplot(x='freedom', y='happiness_score',data=df2019, ax=ax4)

ax5 = fig.add_subplot(325)
sns.regplot(x='govt_corruption', y='happiness_score',data=df2019, ax=ax5)

ax6 = fig.add_subplot(326)
sns.regplot(x='generosity', y='happiness_score',data=df2019, ax=ax6)

# %% [markdown]
# ## Pearson Correlation:
# <p>The Pearson Correlation measures the linear dependence between two variables X and Y.</p>
# <p>The resulting coefficient is a value between -1 and 1 inclusive, where:</p>
# <ul>
#     <li><b>1</b>: Total positive linear correlation.</li>
#     <li><b>0</b>: No linear correlation, the two variables most likely do not affect each other.</li>
#     <li><b>-1</b>: Total negative linear correlation.</li>
# </ul>
# <p>Pearson Correlation is the default method of the function "corr".  Like before we can calculate the Pearson Correlation of the of the 'int64' or 'float64'  variables.</p>

# %% [markdown]
# ### P-value:
# <p>What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.</p>
#
# By convention, when the
# <ul>
#     <li>p-value is $<$ 0.001: we say there is strong evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.05: there is moderate evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.1: there is weak evidence that the correlation is significant.</li>
#     <li>the p-value is $>$ 0.1: there is no evidence that the correlation is significant.</li>
# </ul>

# %%
from scipy import stats

# %% [markdown]
# **Family vs Happiness score**

# %%
pearson_coef,p_value=stats.pearsonr(df['family'],df['happiness_score'])
print(pearson_coef,p_value)
# Out:
# 0.6512455337883003 1.9526702588910346e-95

# %% [markdown]
# ##### Conclusion:
#
# Since the p-value is < 0.001, the correlation between width and price is statistically significant, and the linear relationship is moderately strong (~0.651).

# %% [markdown]
# **Gdp vs Happiness Score**

# %%
pearson_coef,p_value=stats.pearsonr(df['gdp'],df['happiness_score'])
print(pearson_coef,p_value)
# Out:
# 0.7897194831511539 1.7708951779479324e-167

# %% [markdown]
# ##### Conclusion:
#
# Since the p-value is < 0.001, the correlation between width and price is statistically significant, and the linear relationship is quite strong (~0.7897)

# %% [markdown]
# ****Life expectancy vs Happiness Score****

# %%
pearson_coef,p_value=stats.pearsonr(df['life_expectancy'],df['happiness_score'])
print(pearson_coef,p_value)
# Out:
# 0.7428427907457954 6.716673776218217e-138

# %% [markdown]
# ##### Conclusion:
#
# Since the p-value is < 0.001, the correlation between width and price is statistically significant, and the linear relationship is quite strong (~0.743).

# %% [markdown]
# ****Freedom vs Happiness****

# %%
pearson_coef,p_value=stats.pearsonr(df['freedom'],df['happiness_score'])
print(pearson_coef,p_value)
# Out:
# 0.5533649208776603 7.403249086581645e-64

# %% [markdown]
# ##### Conclusion:
#
# Since the p-value is < 0.001, the correlation between width and price is statistically significant, and the linear relationship is moderately strong (~0.553).

# %% [markdown]
# ****Govt curruption vs Happiness score****

# %%
pearson_coef,p_value=stats.pearsonr(df['govt_corruption'],df['happiness_score'])
print(pearson_coef,p_value)
# Out:
# 0.3984178569492507 4.109305584936741e-31

# %% [markdown]
# ##### Conclusion:
#
# Since the p-value is < 0.001, the correlation between width and price is statistically significant, and the linear relationship is  positive strong (0.4).

# %% [markdown]
# Generosity vs Happiness score

# %%
pearson_coef,p_value=stats.pearsonr(df['generosity'],df['happiness_score'])
print(pearson_coef,p_value)
# Out:
# 0.13814208092225352 0.00010751691024295767

# %% [markdown]
# ##### Conclusion:
#
# Since the p-value is < 0.001, the correlation between width and price is statistically significant, and the linear relationship is weak. (~0.138).

# %% [markdown]
# # Models

# %%
data=df.groupby('country')['happiness_score','family','gdp','life_expectancy','freedom','govt_corruption'].mean().reset_index()

x=df[['family','gdp','life_expectancy','freedom','govt_corruption']]
y=df['happiness_score']
# Out:
# C:\Users\Rajat deoli\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=50)
x_train.head()
# Out:
#       family      gdp  life_expectancy  freedom  govt_corruption
# 104  0.95348  0.59532           0.6951  0.40148          0.06825
# 62   1.47500  0.85500           0.7770  0.51400          0.08000
# 23   1.47200  1.32400           1.0450  0.43600          0.18300
# 45   0.80975  0.87370           0.5960  0.37269          0.10613
# 96   1.51300  1.09200           0.8150  0.31100          0.00400

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lm1=LinearRegression()
lm1.fit(x_train,y_train)
yhat1_test=lm1.predict(x_test)

# %%
yhat1_train=lm1.predict(x_train)

# %%
lm1.coef_
# Out:
# array([0.58898068, 1.15774276, 0.9539103 , 1.68261608, 0.91280582])

# %%
lm1.intercept_
# Out:
# 2.286580972256091

# %% [markdown]
# R^2/R-squared value and mean square value(mse) to evaluate the model

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
r2_1=r2_score(y_test,yhat1_test)
r2_1
# Out:
# 0.7967307388890396

# %%
mse1=mean_squared_error(y_test,yhat1_test)
mse1
# Out:
# 0.27842805907131146

# %% [markdown]
# ### Random forest

# %%
from sklearn.ensemble import RandomForestRegressor
ran=RandomForestRegressor(n_estimators=100)
ran.fit(x_train,y_train)
yhat2_test=ran.predict(x_test)

# %%
yhat2_train=ran.predict(x_train)

# %% [markdown]
# R^2/R-squared value and mean square value(mse) to evaluate the model

# %%
r2_2=r2_score(y_test,yhat2_test)
r2_2
# Out:
# 0.8494696709745537

# %%
mse2=mean_squared_error(y_test,yhat2_test)
mse2
# Out:
# 0.20618890978819512

# %% [markdown]
# ### Lasso

# %%
from sklearn.linear_model import Lasso

# %%
lasso_reg=Lasso(normalize=True)
lasso_reg.fit(x_train,y_train)
yhat3=lasso_reg.predict(x_test)

# %% [markdown]
# R^2/R-squared value and mean square value(mse) to evaluate the model

# %%
r2_3=r2_score(y_test,yhat3)
r2_3
# Out:
# -0.00033011349611689056

# %%
mse3=mean_squared_error(y_test,yhat3)
mse3
# Out:
# 1.370202117177325

# %% [markdown]
# ### Bayesian ridge

# %%
from sklearn.linear_model import BayesianRidge
br=BayesianRidge(n_iter=3000,tol=0.5)

# %%
br.fit(x_train,y_train)
yhat4=br.predict(x_test)

# %% [markdown]
# R^2/R-squared value and mean square value(mse) to evaluate the model

# %%
r2_4=r2_score(y_test,yhat4)
r2_4
# Out:
# 0.7966898352658462

# %%
mse4=mean_squared_error(y_test,yhat4)
mse4
# Out:
# 0.2784840868068994

# %% [markdown]
# #### **Conclusion:**
# We came up with that that from Random forest we get highest value of r^2 and lowest mean square value

# %% [markdown]
# ## Distribution plot for Visualization of of our predicted value and actual value

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))

    ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)

    plt.title(Title)


    plt.show()
    plt.close()

# %%
Title = 'Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_train, yhat2_train, "Actual Values (Train)", "Predicted Values (Train)", Title)

# %%
Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'
DistributionPlot(y_test,yhat2_test,"Actual Values (Test)","Predicted Values (Test)",Title)

# %% [markdown]
# # Conclusion
# This is very helpful because you will get know that the factors important for happiness of a nation.
# Here we can see that the happiness is highly correlated to *GDP* and *Healthy Life expectancy* and, a strong correlation with *people social support* and *Freedom*.
# Also *generoisity* and *corruption* is the least correlated to Happiness.
